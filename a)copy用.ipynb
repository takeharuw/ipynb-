# %%
# %%

import time
import openpyxl as xl
import openpyxl, pprint
from openpyxl import load_workbook
from openpyxl.formula.translate import Translator
from openpyxl.worksheet.datavalidation import DataValidation
from openpyxl.styles.borders import Border, Side
from openpyxl.styles import PatternFill
import pandas as pd
import numpy as np
import os
import csv
import sys
from time import sleep
import datetime
import glob
import shutil
import subprocess
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoAlertPresentException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from operator import itemgetter
import requests
from bs4 import BeautifulSoup
from urllib import request
import pyperclip
import pyautogui as gui
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome import service as fs
from copy import copy
import tkinter as tk
from tkinter import filedialog
from selenium.webdriver.chrome.service import Service as ChromeService


# %%

# %%
作業名 = "WMSAPI作業"


import requests

def send_line_message(token, message):
    url = 'https://notify-api.line.me/api/notify'
    headers = {'Authorization': f'Bearer {token}'}
    payload = {'message': message}
    response = requests.post(url, headers=headers, data=payload)
    return response

# トークンと送信するメッセージを指定
token = 'en2eb5DkiPnEhTeufOWKac3fWvBoFsmIsKu6xevUX7W'
message = 作業名 + '開始'

# メッセージを送信
send_line_message(token, message)

# %%
td = datetime.datetime.today()

da = datetime.timedelta(days=4)
db = datetime.timedelta(days=8)

kaisi = td + da
syuuryou = td + db

開始日 = kaisi.strftime("%Y/%m/%d")
終了日 = syuuryou.strftime("%Y/%m/%d")

kyou = td.strftime("%Y%m%d")



# カレントディレクトリの取得
current_dir = os.getcwd()

# 一時ダウンロードフォルダパスの設定
tmp_download_dir = f'{current_dir}\\tmpDownload'

# 一時フォルダが存在していたら消す
if os.path.isdir(tmp_download_dir):
    shutil.rmtree(tmp_download_dir)

# 一時ダウンロードフォルダの作成
os.mkdir(tmp_download_dir)


sleep(3)


# Chromeオプション設定でダウンロード先を変更
options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : tmp_download_dir }
options.add_experimental_option('prefs',prefs)
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options = options)

print("5")





j = 0
while j < 2:
    try:
        driver.get('https://maruhan.lightning.force.com/lightning/r/Report/00O0I00000B3s3MUAR/edit')
        driver.find_element(by="id", value="username").send_keys("east-yuugiki@maruhan.co.jp")
        driver.find_element(by="id", value="password").send_keys("eastmaruhan07")
        driver.find_element(by="xpath", value="//*[@id='Login']").click()
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        time.sleep(10)
        continue
    else:
        break
sleep(10)




#########  SFの条件変更  #############


# iframe要素を探し、それにスイッチします。
iframe = driver.find_element(By.CSS_SELECTOR, "#brandBand_2 > div > div > div > iframe")
driver.switch_to.frame(iframe)
sleep(1)  # 処理が上手くいくように少し待つ

# タブのタイトルをクリックします。
driver.find_elements(By.XPATH, '//h2[@class="tab-title"]')[1].click()
sleep(1)  # click操作後の適切な処理のために少し待つ

# <button>要素を検索してクリックします。条件はtype属性が'button'で、子要素のspanタグのテキストが'点検予定日'であることです。
element = driver.find_element(By.XPATH, "//button[@type='button' and ./span[text()='点検予定日']]").click()

# "filter-widget"クラス名を持つ親要素を検索します。
parent_element = driver.find_element(By.CLASS_NAME, "filter-widget")

# 同じ親要素内で"slds-input"クラス名を持つ全ての要素を検索します。
elements = parent_element.find_elements(By.CLASS_NAME, "slds-input")


elements[1].clear()    # 要素の内容をクリアする
sleep(0.5)             # 操作の間に少し待つ
elements[1].send_keys(開始日)   # 開始日を入力
sleep(0.5)             # 操作の間に少し待つ
elements[2].clear()    # 要素の内容をクリアする
sleep(0.5)             # 操作の間に少し待つ
elements[2].send_keys(終了日)   # 終了日を入力
sleep(0.5)             # 操作の間に少し待つ


# "適用"のテキストを含む<button>要素をクリックします。 
driver.find_element(By.XPATH, "//button[contains(text(), '適用')]").click()
sleep(3)  # 処理がていねいに実行されるように少し待つ

# "実行"のテキストを含む<button>要素をクリックします。 
driver.find_element(By.XPATH, "//button[contains(text(), '実行')]").click()
sleep(10)  # ページの読み込みや処理に時間がかかる場合を想定して長めに待つ




j = 0
while j < 2:
    try:
        driver.get('https://maruhan.lightning.force.com/lightning/r/Report/00O0I00000B3s3MUAR/view')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        time.sleep(10)
        continue
    else:
        break
sleep(10)



#########  SFのレポート出力  #############




iframe = driver.find_element(By.CSS_SELECTOR, "#brandBand_2 > div > div > div > iframe")
driver.switch_to.frame(iframe)
sleep(1)


#編集をクリック
driver.find_element(By.XPATH, "//*[contains(@class, 'slds-dropdown-trigger slds-dropdown-trigger_click slds-button_last')]").click()
sleep(1)


#エクスポートをクリック
driver.find_element(By.XPATH, "//*[contains(@class, 'slds-dropdown__item actionBarButtonGroup-action-item item report-action-ReportExportAction')]").click()
sleep(1)


#元のwindowに戻す
driver.switch_to.default_content()
sleep(1)


#詳細のみをクリック
driver.find_element(By.XPATH, '//*[contains(text(), "詳細のみ")]').click()
sleep(1)


#csvをクリック
driver.find_element(By.XPATH, '//*[contains(text(), "カンマ区切り形式 (.csv)")]').click()
sleep(1)


#日本語 (Shift-JIS)をクリック
driver.find_element(By.XPATH, '//*[contains(text(), "日本語 (Shift-JIS)")]').click()
sleep(1)


#エクスポートをクリック
driver.find_element(By.XPATH, "//button[@title='エクスポート']").click()


# 待機タイムアウト時間(秒)設定
timeout_second = 30

# 指定時間分待機
for i in range(timeout_second + 1):
    # ファイル一覧取得
    download_fileName = glob.glob(f'{tmp_download_dir}\\*.*')

    # ファイルが存在する場合
    if download_fileName:
        # 拡張子の抽出
        extension = os.path.splitext(download_fileName[0])

        # 拡張子が '.crdownload' ではない ダウンロード完了 待機を抜ける
        if ".crdownload" not in extension[1]:
            time.sleep(2)
            break

    # 指定時間待っても .crdownload 以外のファイルが確認できない場合 エラー
    if i >= timeout_second:
        # == エラー処理をここに記載 ==
        # 終了処理
        driver.quit()
        # 一時フォルダの削除
        shutil.rmtree(tmp_download_dir)
        sys.exit()

    # 一秒待つ
    time.sleep(5)

sleep(3)



files=glob.glob(f'{tmp_download_dir}\\*.*')
for file in files:
    tenken = pd.read_csv(file, encoding="cp932", engine='python')

for deletefile in glob.glob(f'{tmp_download_dir}\\*.*'):
    os.remove(deletefile)

sleep(2)

# %%
pd.set_option('display.max_rows', None)
tenken

# %%
j = 0
while j < 2:
    try:
        driver.get('https://maruhan.lightning.force.com/lightning/r/Report/00O0I00000B3sFNUAZ/edit')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        time.sleep(10)
        continue
    else:
        break
sleep(10)








# %%

#########  SFの条件変更  #############


# iframe要素を探し、それにスイッチします。
iframe = driver.find_element(By.CSS_SELECTOR, "#brandBand_2 > div > div > div > iframe")
driver.switch_to.frame(iframe)
sleep(1)  # 処理が上手くいくように少し待つ

# タブのタイトルをクリックします。
driver.find_elements(By.XPATH, '//h2[@class="tab-title"]')[1].click()
sleep(1)  # click操作後の適切な処理のために少し待つ

# <button>要素を検索してクリックします。条件はtype属性が'button'で、子要素のspanタグのテキストが'点検予定日'であることです。
element = driver.find_element(By.XPATH, "//button[@type='button' and ./span[text()='点検予定日']]").click()

# "filter-widget"クラス名を持つ親要素を検索します。
parent_element = driver.find_element(By.CLASS_NAME, "filter-widget")

# 同じ親要素内で"slds-input"クラス名を持つ全ての要素を検索します。
elements = parent_element.find_elements(By.CLASS_NAME, "slds-input")


elements[1].clear()    # 要素の内容をクリアする
sleep(0.5)             # 操作の間に少し待つ
elements[1].send_keys(開始日)   # 開始日を入力
sleep(0.5)             # 操作の間に少し待つ
elements[2].clear()    # 要素の内容をクリアする
sleep(0.5)             # 操作の間に少し待つ
elements[2].send_keys(終了日)   # 終了日を入力
sleep(0.5)             # 操作の間に少し待つ


# "適用"のテキストを含む<button>要素をクリックします。 
driver.find_element(By.XPATH, "//button[contains(text(), '適用')]").click()
sleep(3)  # 処理がていねいに実行されるように少し待つ

# "実行"のテキストを含む<button>要素をクリックします。 
driver.find_element(By.XPATH, "//button[contains(text(), '実行')]").click()
sleep(10)  # ページの読み込みや処理に時間がかかる場合を想定して長めに待つ

# %%



j = 0
while j < 2:
    try:
        driver.get('https://maruhan.lightning.force.com/lightning/r/Report/00O0I00000B3sFNUAZ/view')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        time.sleep(10)
        continue
    else:
        break
sleep(10)








# %%

#########  SFのレポート出力  #############




iframe = driver.find_element(By.CSS_SELECTOR, "#brandBand_2 > div > div > div > iframe")
driver.switch_to.frame(iframe)
sleep(1)


#編集をクリック
driver.find_element(By.XPATH, "//*[contains(@class, 'slds-dropdown-trigger slds-dropdown-trigger_click slds-button_last')]").click()
sleep(1)


#エクスポートをクリック
driver.find_element(By.XPATH, "//*[contains(@class, 'slds-dropdown__item actionBarButtonGroup-action-item item report-action-ReportExportAction')]").click()
sleep(1)


#元のwindowに戻す
driver.switch_to.default_content()
sleep(1)


#詳細のみをクリック
driver.find_element(By.XPATH, '//*[contains(text(), "詳細のみ")]').click()
sleep(1)


#csvをクリック
driver.find_element(By.XPATH, '//*[contains(text(), "カンマ区切り形式 (.csv)")]').click()
sleep(1)


#日本語 (Shift-JIS)をクリック
driver.find_element(By.XPATH, '//*[contains(text(), "日本語 (Shift-JIS)")]').click()
sleep(1)


#エクスポートをクリック
driver.find_element(By.XPATH, "//button[@title='エクスポート']").click()

# 待機タイムアウト時間(秒)設定
timeout_second = 30

# 指定時間分待機
for i in range(timeout_second + 1):
    # ファイル一覧取得
    download_fileName = glob.glob(f'{tmp_download_dir}\\*.*')

    # ファイルが存在する場合
    if download_fileName:
        # 拡張子の抽出
        extension = os.path.splitext(download_fileName[0])

        # 拡張子が '.crdownload' ではない ダウンロード完了 待機を抜ける
        if ".crdownload" not in extension[1]:
            time.sleep(2)
            break

    # 指定時間待っても .crdownload 以外のファイルが確認できない場合 エラー
    if i >= timeout_second:
        # == エラー処理をここに記載 ==
        # 終了処理
        driver.quit()
        # 一時フォルダの削除
        shutil.rmtree(tmp_download_dir)
        sys.exit()

    # 一秒待つ
    time.sleep(5)

sleep(3)



# %%

sleep(1)

files=glob.glob(f'{tmp_download_dir}\\*.*')
for file in files:
    minyuu = pd.read_csv(file, encoding="cp932", skipfooter=5, engine='python')

for deletefile in glob.glob(f'{tmp_download_dir}\\*.*'):
    os.remove(deletefile)

sleep(2)


# %%


j = 0
while j < 2:
    try:
        driver.get('https://maruhan.lightning.force.com/lightning/r/Report/00O0I00000B3s3W/view')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        time.sleep(10)
        continue
    else:
        break
sleep(10)



# %%

#########  SFのレポート出力  #############




iframe = driver.find_element(By.CSS_SELECTOR, "#brandBand_2 > div > div > div > iframe")
driver.switch_to.frame(iframe)
sleep(1)


#編集をクリック
driver.find_element(By.XPATH, "//*[contains(@class, 'slds-dropdown-trigger slds-dropdown-trigger_click slds-button_last')]").click()
sleep(1)


#エクスポートをクリック
driver.find_element(By.XPATH, "//*[contains(@class, 'slds-dropdown__item actionBarButtonGroup-action-item item report-action-ReportExportAction')]").click()
sleep(1)


#元のwindowに戻す
driver.switch_to.default_content()
sleep(1)


#詳細のみをクリック
driver.find_element(By.XPATH, '//*[contains(text(), "詳細のみ")]').click()
sleep(1)


#csvをクリック
driver.find_element(By.XPATH, '//*[contains(text(), "カンマ区切り形式 (.csv)")]').click()
sleep(1)


#日本語 (Shift-JIS)をクリック
driver.find_element(By.XPATH, '//*[contains(text(), "日本語 (Shift-JIS)")]').click()
sleep(1)


#エクスポートをクリック
driver.find_element(By.XPATH, "//button[@title='エクスポート']").click()

# 待機タイムアウト時間(秒)設定
timeout_second = 30

# 指定時間分待機
for i in range(timeout_second + 1):
    # ファイル一覧取得
    download_fileName = glob.glob(f'{tmp_download_dir}\\*.*')

    # ファイルが存在する場合
    if download_fileName:
        # 拡張子の抽出
        extension = os.path.splitext(download_fileName[0])

        # 拡張子が '.crdownload' ではない ダウンロード完了 待機を抜ける
        if ".crdownload" not in extension[1]:
            time.sleep(2)
            break

    # 指定時間待っても .crdownload 以外のファイルが確認できない場合 エラー
    if i >= timeout_second:
        # == エラー処理をここに記載 ==
        # 終了処理
        driver.quit()
        # 一時フォルダの削除
        shutil.rmtree(tmp_download_dir)
        sys.exit()

    # 一秒待つ
    time.sleep(5)

sleep(3)



# %%

files=glob.glob(f'{tmp_download_dir}\\*.*')
for file in files:
    kyoten = pd.read_csv(file, encoding="cp932", skipfooter=5, engine='python')

for deletefile in glob.glob(f'{tmp_download_dir}\\*.*'):
    os.remove(deletefile)

sleep(2)

# %%
# %%
# dfの加工

kyoten = kyoten.rename(columns={'名称':'店舗名'})

tenkenminyuu = minyuu.merge(kyoten, on='店舗名', how='left')
tenkenminyuu = tenkenminyuu.drop_duplicates()
tenkenminyuu = tenkenminyuu.reset_index()
tenkenminyuu = tenkenminyuu.drop(columns=['index', '店舗名'])


tenkennyuuryoku = tenken.merge(kyoten, on='店舗名', how='left')
tenkennyuuryoku = tenkennyuuryoku.drop_duplicates()
tenkennyuuryoku = tenkennyuuryoku.reset_index()

tenkennyuuryoku = tenkennyuuryoku.drop(columns=['index', '店舗名'])


tenkennyuuryoku = tenkennyuuryoku.assign(所在=4)
tenkenminyuu = tenkenminyuu.assign(所在=3)


tenkennyuuryoku = pd.concat([tenkennyuuryoku, tenkenminyuu],ignore_index=True)

tenken = pd.concat([tenken, minyuu],ignore_index=True)

sleep(1)

# %%
tenkennyuuryoku

# %%
pd.set_option('display.max_rows', None)
tenken

# %%
# API送信

driver.get('https://ieu7K2dKFi2:AAieus84k32d@www2.p-logistech.com/ams2/xapi/shipping/add')
sleep(3)

ur = []
kr = []
for i in  range(len(tenkennyuuryoku['機種資産/資産台帳: WMS TC01入庫'])):
    
    TC01 = tenkennyuuryoku['機種資産/資産台帳: WMS TC01入庫'][i]
    TC11 = tenkennyuuryoku['WMS拠点コード'][i]
    TC15 = tenkennyuuryoku['点検予定日'][i]
    TC16 = tenkennyuuryoku['所在'][i]
    
    URL = f'https://www2.p-logistech.com/ams2/xapi/shipping/add?TC01={TC01}&TC11={TC11}&TC15={TC15}&TC16={TC16}&TC100=SELL2'
    driver.get(URL)
    ur.append(URL)
    
    kakuninn = driver.find_elements(by="xpath", value='/html/body')[0].text
    kr.append(kakuninn)




# %%
urdf = pd.DataFrame({'リクエスト':ur})
krdf = pd.DataFrame({'入力判断':kr})

nyuuryokurennraku = pd.concat([tenken,krdf,urdf],axis=1)

nyuuryokurennraku.to_excel(f"D:/DC点検入力/入力処理リスト{kyou}.xlsx",index=False)

sleep(1)

# %%
# ガルーンログイン
j = 0
while j < 2:
    try:
        driver.get('https://mrh-garoon.cybozu.com/g/space/application/discussion/index.csp?spid=995&sf=1#tid=29098&sp=')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        time.sleep(10)
        continue
    else:
        break
sleep(3)




# %%

# メッセージ入力
messe = driver.find_element(by=By.XPATH, value='/html/body/div[2]/div[1]/div/div[3]/div[1]/table/tbody/tr/td[2]/div/div/div/div[2]/div[1]/form/div[2]/div[3]/textarea[1]')
messe.send_keys("ＷＭＳの点検入力を実行しました。内容の確認をして下さい（自動メッセージ）")
sleep(1)

# ファイル添付
mail_temp1 = driver.find_element(by=By.XPATH, value='//*[@id="file_upload_thread_comment"]')
mail_temp1.send_keys(f'D:/DC点検入力/入力処理リスト{kyou}.xlsx')

sleep(5)




# メッセージの変更
driver.find_element(by=By.XPATH, value='//*[@id="thread_comment_button"]/a').click()
sleep(2)



# 一時フォルダを消す
if os.path.isdir(tmp_download_dir):
    shutil.rmtree(tmp_download_dir)

sleep(3)








# %%


##＃＃＃＃＃＃＃＃＃##
# 作業完了メッセージ #
##＃＃＃＃＃＃＃＃＃##

j = 0
while j < 2:
    try:
        driver.get('https://mrh-garoon.cybozu.com/g/message/view.csp?cid=268699&rid=11041431&mid=3274447')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        sleep(10)
        continue
    else:
        break
sleep(1)

#コメント入力
driver.find_element(by="id", value="data_editor_id").send_keys(作業名 + "が完了")
sleep(1)

#書き込み
driver.find_element(by="id", value="message_comment_button_save").click()
sleep(1)

#ブラウザダウン
driver.quit()

sleep(3)

message = 作業名 + '終了'

# メッセージを送信
send_line_message(token, message)

# %%
from dateutil.relativedelta import relativedelta
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoAlertPresentException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome import service as fs
from selenium.common.exceptions import TimeoutException
from time import sleep
from datetime import datetime, timedelta

import os
import time
import shutil
import glob
import pandas as pd
import numpy as np
import math
import xlwings as xw
import sys
import pywinauto
import platform




作業名 = "○○作業"





# カレントディレクトリの取得
current_dir = os.getcwd()

# 一時ダウンロードフォルダパスの設定
tmp_download_dir = f'{current_dir}\\tmpDownload'

# 一時フォルダが存在していたら消す
if os.path.isdir(tmp_download_dir):
    shutil.rmtree(tmp_download_dir)

# 一時ダウンロードフォルダの作成
os.mkdir(tmp_download_dir)


sleep(3)


# Chromeオプション設定でダウンロード先を変更
options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : tmp_download_dir }
options.add_experimental_option('prefs',prefs)
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options = options)


# データをリストに格納
data = [
    ["DC", "企業／業者ID", "ログインID", "パスワード"],
    ["埼玉", "04906", "maruhan001", "maruhan001"],
    ["群馬", "04906", "maruhan002", "maruhan002"],
    ["静岡", "04624", "maruhan003", "maruhan003"]
]

# DataFrameを作成
df = pd.DataFrame(data[1:], columns=data[0])

for index, row in df.iterrows():
    dc = row["DC"]
    cd = row["企業／業者ID"]
    id = row["ログインID"]
    pas = row["パスワード"]

# %% [markdown]
# ##＃＃＃＃＃＃＃＃＃##
# # 作業開始メッセージ #
# ##＃＃＃＃＃＃＃＃＃##
#
# j = 0
# while j < 2:
#     try:
#         driver.get('https://mrh-garoon.cybozu.com/g/message/view.csp?cid=268699&rid=11041431&mid=3274447')
#         driver.find_element(by="name", value="username").send_keys("1125324")
#         driver.find_element(by="name", value="password").send_keys("haru0287450088")
#         driver.find_element(by="xpath", value="/html/body/div[4]/div/div[2]/form/div[4]/div[2]/input").click()
#     except TimeoutException:
#         j = j + 1
#         print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
#         sleep(10)
#         continue
#     else:
#         break
# sleep(1)
#
# #コメント入力
# driver.find_element(by="id", value="data_editor_id").send_keys(作業名 + "を開始")
# sleep(1)
#
# #書き込み
# driver.find_element(by="id", value="message_comment_button_save").click()
# sleep(1)

# %%
dc

# %%
cd

# %%
id

# %%
pas

# %%
j = 0
while j < 2:
    try:
        driver.get('https://lp-trace.nittsu.co.jp/lgn/')
        driver.find_element(By.NAME, "enterpriseID").send_keys(cd)
        driver.find_element(By.NAME, "userID").send_keys(id)
        driver.find_element(By.NAME, "inputPassword").send_keys(pas)
        driver.find_element(By.ID, "loginBtn").click()
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        sleep(10)
        continue
    else:
        break
sleep(1)


#クリックする要素
element = driver.find_element(By.ID, "A3-0")

#(リンク)要素を新しいタブで開く
actions = ActionChains(driver)

#コントロールキー
actions.key_down(Keys.CONTROL)

actions.click(element)
actions.perform()

sleep(2)



# タブのウィンドウハンドルを取得
window_handles = driver.window_handles
sleep(0.5)

# 3番目のタブを閉じる
driver.switch_to.window(window_handles[1])
driver.close()
sleep(0.5)


window_handles = driver.window_handles
sleep(0.5)

# 2番目タブを選択
driver.switch_to.window(window_handles[1])
sleep(0.5)


#フレームの選択
driver.switch_to.frame("FRAME1")

# 要素を検索してクリック
element = driver.find_element("css selector", "#tlpasiaa031")
element.click()

# 元のフレームに戻る
driver.switch_to.default_content()

# FRAME2に切り替え
driver.switch_to.frame("FRAME2")



# 現在の日付を取得
today = datetime.today()

# 昨日の日付を計算
yesterday = today - timedelta(days=1)


# 日付をフォーマット
formatted_date = today.strftime("%Y/%m/%d")
#formatted_date = yesterday.strftime("%Y/%m/%d")
# フォーマットされた日付を表示
print(formatted_date)
sleep(0.5)





# 発送日の入力
driver.find_element("css selector", "input[name='formValue(hasso_ymd_from)']").clear()
sleep(1)
driver.find_element("css selector", "input[name='formValue(hasso_ymd_to)']").clear()
sleep(1)
driver.find_element("css selector", "input[name='formValue(hasso_ymd_from)']").send_keys(formatted_date)
sleep(1)
driver.find_element("css selector", "input[name='formValue(hasso_ymd_to)']").send_keys(formatted_date)
sleep(1)
driver.find_element("css selector", "input[name='formValue(hasso_ymd_from)']").send_keys(formatted_date)
sleep(1)

# ドロップダウン要素を検索
dropdown = driver.find_element("css selector", "select[name='formValue(keirekisoushin_kbn)']")
# Selectオブジェクトを作成
select = Select(dropdown)
# 値に基づいてオプションを選択
select.select_by_value("30")


#検索実行
driver.find_element(By.ID, "search_btn").click()

#全選択
driver.find_element(By.NAME, "allcheck").click()

#ダウンロード実行
driver.find_element(By.ID, "btnDownload1").click()

sleep(3)


# 全てのIframeを取得
iframes = driver.find_elements("tag name", "iframe")

# 各Iframeのidを表示
for iframe in iframes:
    iframe_id = iframe.get_attribute("id")
    print(iframe_id)
sleep(2)

# %%
# 外側のIFrameに切り替え
outer_iframe = driver.find_element("css selector", "iframe#ifrm_outputSyubetu")
driver.switch_to.frame(outer_iframe)

# 内側のIFrameに切り替え
inner_iframe = driver.find_element("css selector", "iframe#dispIframe")
driver.switch_to.frame(inner_iframe)

# 内側のIFrame内の要素を操作
option_element = driver.find_element(By.XPATH, "//option[contains(text(), '自動メール用')]")
option_element.click()


driver.find_element("css selector", "input[name='return']").click()
sleep(1)

# %%
# アラートを受け取る
alert = driver.switch_to.alert
# "OK"をクリック
alert.accept()
sleep(1)





# 元のフレームに戻る
driver.switch_to.default_content()

# FRAME2に切り替え
driver.switch_to.frame("FRAME1")



driver.find_element(By.ID, "tlpacmaa181").click()


# 元のフレームに戻る
driver.switch_to.default_content()

# FRAME2に切り替え
driver.switch_to.frame("FRAME2")


driver.find_element(By.ID, "btn_search").click()
sleep(3)


# 全ての要素を取得
elements = driver.find_elements(By.CSS_SELECTOR, "td.text-left.cell-pd0")

# index番号3の要素の値を取得
element = elements[3]
text = element.text

while text == "作成中":
    sleep(3)
    driver.find_element(By.ID, "btn_search").click()


if text == "作成済":
    driver.find_element(By.ID, "0").click()
    sleep(1)
    
    
    # アラートを受け取る
    alert = driver.switch_to.alert
    # "OK"をクリック
    alert.accept()
    sleep(1)

    # 待機タイムアウト時間(秒)設定
    timeout_second = 30

    # 指定時間分待機
    for i in range(timeout_second + 1):
        # ファイル一覧取得
        download_fileName = glob.glob(f'{tmp_download_dir}\\*.*')

        # ファイルが存在する場合
        if download_fileName:
            # 拡張子の抽出
            extension = os.path.splitext(download_fileName[0])

            # 拡張子が '.crdownload' ではない ダウンロード完了 待機を抜ける
            if ".crdownload" not in extension[1]:
                sleep(2)
                break

        # 指定時間待っても .crdownload 以外のファイルが確認できない場合 エラー
        if i >= timeout_second:
            # == エラー処理をここに記載 ==
            # 終了処理
            driver.quit()
            # 一時フォルダの削除
            shutil.rmtree(tmp_download_dir)
            sys.exit()

        # 一秒待つ
        sleep(5)

    sleep(3)

    #移動ファイル指定
    Nowfile = glob.glob(f'{tmp_download_dir}\\*.*')
    file = Nowfile[0]

    # 新しいファイルパス
    new_file_path = f'C:/Users/1125324/Desktop/送り状メール/{dc}.csv'
    # ファイル名変更
    os.rename(file, new_file_path)
    
    
else:
    print("Text:", text)

# %%
# 外側のIFrameに切り替え
outer_iframe = driver.find_element("css selector", "iframe#ifrm_outputSyubetu")
driver.switch_to.frame(outer_iframe)

# 内側のIFrameに切り替え
inner_iframe = driver.find_element("css selector", "iframe#dispIframe")
driver.switch_to.frame(inner_iframe)

# 内側のIFrame内の要素を操作
option_element = driver.find_element(By.XPATH, "//option[contains(text(), '自動メール用')]")
option_element.click()


driver.find_element("css selector", "input[name='return']").click()
sleep(1)

# アラートを受け取る
alert = driver.switch_to.alert
# "OK"をクリック
alert.accept()
sleep(1)

# %%
# 元のフレームに戻る
driver.switch_to.default_content()

# FRAME2に切り替え
driver.switch_to.frame("FRAME1")

# %%
driver.find_element(By.ID, "tlpacmaa181").click()


# 元のフレームに戻る
driver.switch_to.default_content()

# FRAME2に切り替え
driver.switch_to.frame("FRAME2")



driver.find_element(By.ID, "btn_search").click()
sleep(3)

# %%
# 全ての要素を取得
elements = driver.find_elements(By.CSS_SELECTOR, "td.text-left.cell-pd0")

# index番号3の要素の値を取得
element = elements[3]
text = element.text

while text == "作成中":
    sleep(3)
    driver.find_element(By.ID, "btn_search").click()


if text == "作成済":
    driver.find_element(By.ID, "0").click()
    sleep(1)
    
    
    # アラートを受け取る
    alert = driver.switch_to.alert
    # "OK"をクリック
    alert.accept()
    sleep(1)

    # 待機タイムアウト時間(秒)設定
    timeout_second = 30

    # 指定時間分待機
    for i in range(timeout_second + 1):
        # ファイル一覧取得
        download_fileName = glob.glob(f'{tmp_download_dir}\\*.*')

        # ファイルが存在する場合
        if download_fileName:
            # 拡張子の抽出
            extension = os.path.splitext(download_fileName[0])

            # 拡張子が '.crdownload' ではない ダウンロード完了 待機を抜ける
            if ".crdownload" not in extension[1]:
                sleep(2)
                break

        # 指定時間待っても .crdownload 以外のファイルが確認できない場合 エラー
        if i >= timeout_second:
            # == エラー処理をここに記載 ==
            # 終了処理
            driver.quit()
            # 一時フォルダの削除
            shutil.rmtree(tmp_download_dir)
            sys.exit()

        # 一秒待つ
        sleep(5)

    sleep(3)

    #移動ファイル指定
    Nowfile = glob.glob(f'{tmp_download_dir}\\*.*')
    file = Nowfile[0]

    # 新しいファイルパス
    new_file_path = f'C:/Users/1125324/Desktop/送り状メール/{DC}.csv'
    # ファイル名変更
    os.rename(file, new_file_path)
    
    
else:
    print("Text:", text)

# %%
# アラートを受け取る
alert = driver.switch_to.alert
# "OK"をクリック
alert.accept()
sleep(1)

# 待機タイムアウト時間(秒)設定
timeout_second = 30

# 指定時間分待機
for i in range(timeout_second + 1):
    # ファイル一覧取得
    download_fileName = glob.glob(f'{tmp_download_dir}\\*.*')

    # ファイルが存在する場合
    if download_fileName:
        # 拡張子の抽出
        extension = os.path.splitext(download_fileName[0])

        # 拡張子が '.crdownload' ではない ダウンロード完了 待機を抜ける
        if ".crdownload" not in extension[1]:
            sleep(2)
            break

    # 指定時間待っても .crdownload 以外のファイルが確認できない場合 エラー
    if i >= timeout_second:
        # == エラー処理をここに記載 ==
        # 終了処理
        driver.quit()
        # 一時フォルダの削除
        shutil.rmtree(tmp_download_dir)
        sys.exit()

    # 一秒待つ
    sleep(5)

sleep(3)

#移動ファイル指定
Nowfile = glob.glob(f'{tmp_download_dir}\\*.*')
file = Nowfile[0]

# 新しいファイルパス
new_file_path = f'C:/Users/1125324/Desktop/送り状メール/{DC}.csv'
# ファイル名変更
os.rename(file, new_file_path)

# %%
##＃＃＃＃＃＃＃＃＃##
# 作業完了メッセージ #
##＃＃＃＃＃＃＃＃＃##

j = 0
while j < 2:
    try:
        driver.get('https://mrh-garoon.cybozu.com/g/message/view.csp?cid=268699&rid=11041431&mid=3274447')
    except TimeoutException:
        j = j + 1
        print("Timeout, Retrying... (%(j)s/%(max)s)" % {'j': j, 'max': 9})
        sleep(10)
        continue
    else:
        break
sleep(1)

#コメント入力
driver.find_element(by="id", value="data_editor_id").send_keys(作業名 + "が完了")
sleep(1)

#書き込み
driver.find_element(by="id", value="message_comment_button_save").click()
sleep(1)

#ブラウザダウン
driver.quit()
